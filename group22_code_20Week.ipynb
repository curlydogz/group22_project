# %%
from gurobipy import *
import csv

##### 20 week Simulation ##########

# ----------------------------------
# Parameters
# -----------------------------------

# County population P[i]
P = {
    "Franklin": 1356303,
    "Delaware": 237966,
    "Licking": 184898,
    "Fairfield": 167762,
    "Union": 71721,
    "Marion": 64976,
    "Knox": 63848,
    "Pickaway": 62158,
    "Logan": 46085,
    "Madison": 45531,
    "Crawford": 41626,
    "Morrow": 35927,
    "Hardin": 30402,
    "Fayette": 28782,
    "Wyandot": 21394
}

# Maximum available clinic square footage S[i] for each county
S = {
    "Franklin": 452082,
    "Delaware": 123766,
    "Licking": 27336,
    "Fairfield": 64526,
    "Union": 314164,
    "Marion": 55737,
    "Knox": 376007,
    "Pickaway": 55507,
    "Logan": 73185,
    "Madison": 49019,
    "Crawford": 50491,
    "Morrow": 144270,
    "Hardin": 30751,
    "Fayette": 159251,
    "Wyandot": 72137
}

# Initial vaccine coverage C[i] in each county (as proportion vaccinated)
C = {
    "Franklin": 0.0,
    "Delaware": 0.0,
    "Licking": 0.0,
    "Fairfield": 0.0,
    "Union": 0.0,
    "Marion": 0.0,
    "Knox": 0.0,
    "Pickaway": 0.0,
    "Logan": 0.0,
    "Madison": 0.0,
    "Crawford": 0.0,
    "Morrow": 0.0,
    "Hardin": 0.0,
    "Fayette": 0.0,
    "Wyandot": 0.0
}


# Set of counties in Region 4
I = [
    "Franklin", "Delaware", "Licking", "Fairfield", "Union",
    "Marion", "Knox", "Pickaway", "Logan", "Madison",
    "Crawford", "Morrow", "Hardin", "Fayette", "Wyandot"
]

# Set of vaccination team types (administrator-to-vaccinator staffing ratios)
K = [
    "1to1",
    "3to1",
    "7to1"
]

# ----------------------------------
# WEEKLY PARAMETERS 
# ----------------------------------

V = {
    1: 150000,
    2: 150000,
    3: 150000,
    4: 150000,
    5: 150000,
    6: 150000,
    7: 150000,
    8: 150000,
    9: 150000,
    10: 150000,
    11: 150000,
    12: 150000,
    13: 150000,
    14: 150000,
    15: 150000,
    16: 150000,
    17: 150000,
    18: 150000,
    19: 150000,
    20: 150000
}

E_V = {
    1: 205,
    2: 205,
    3: 205,
    4: 205,
    5: 205,
    6: 205,
    7: 205,
    8: 205,
    9: 205,
    10: 205,
    11: 205,
    12: 205,
    13: 205,
    14: 205,
    15: 205,
    16: 205,
    17: 205,
    18: 205,
    19: 205,
    20: 205
}

E_A = {
    1: 789,
    2: 789,
    3: 789,
    4: 789,
    5: 789,
    6: 789,
    7: 789,
    8: 789,
    9: 789,
    10: 789,
    11: 789,
    12: 789,
    13: 789,
    14: 789,
    15: 789,
    16: 789,
    17: 789,
    18: 789,
    19: 789,
    20: 789
}

# Number of staff in each team
rV = {"1to1": 1, "3to1": 1, "7to1": 1}
rA = {"1to1": 1, "3to1": 3, "7to1": 7}

# Hourly vaccination rates for each team
vacc_per_hour = {"1to1": 6, "3to1": 19, "7to1": 30}

# Work hours per week
hours_per_week = 40

# Maximum number of people each team type can vaccinate per week
M = {k: vacc_per_hour[k] * hours_per_week for k in K}

# Square footage requirement per team
sqft = 2500

# ----------------------------------
# Results storage
# ----------------------------------
results = []

# ==========================================================
#                  20–WEEK SIMULATION LOOP
# ==========================================================

for week in range(1, 21):

    print(f"\n==================== WEEK {week} ====================\n")
    print("Starting coverage:", C)

    # --------------------------
    # Model
    # --------------------------
    m = Model(f"Week_{week}_Vaccine_Planning")
    m.Params.OutputFlag = 0   # silence solver output

    # Decision variables
    t = m.addVars(I, K, vtype=GRB.INTEGER, lb=0, name="t")
    d = m.addVars(I, vtype=GRB.INTEGER, lb=0, name="d")
    z = m.addVars(I, vtype=GRB.INTEGER, lb=0, name="z")

    # Objective
    m.setObjective(quicksum(z[i] for i in I), GRB.MAXIMIZE)

    # Constraints

    # 1. Weekly vaccine supply
    m.addConstr(quicksum(d[i] for i in I) <= V[week], name="VaccineSupply")

    # 2. Vaccinator availability
    m.addConstr(quicksum(rV[k] * t[i, k] for i in I for k in K) <= E_V[week],
                name="TotalVaccinators")

    # 3. Admin staff availability
    m.addConstr(quicksum(rA[k] * t[i, k] for i in I for k in K) <= E_A[week],
                name="TotalAdmin")

    for i in I:

        # 4. Dose feasibility
        m.addConstr(z[i] <= d[i], name=f"FeasibleDoses[{i}]")

        # 5. Herd immunity cap
        m.addConstr(z[i] <= (0.8 - C[i]) * P[i], name=f"HerdImmunity[{i}]")

        # 6. Weekly participation limit
        m.addConstr(z[i] <= 0.1 * P[i] * (1 - C[i]), name=f"Participation[{i}]")

        # 7. Building capacity
        m.addConstr(sqft * quicksum(t[i, k] for k in K) <= S[i], name=f"Building[{i}]")

        # 8. Throughput limitation
        m.addConstr(z[i] <= quicksum(M[k] * t[i, k] for k in K), name=f"Throughput[{i}]")


    # 9. Fairness constraint 
    for i in I:
        for j in I:
    
            # Only compare different counties
            if i != j:
    
                m.addConstr((C[i] * P[i] + z[i]) * P[j] - (C[j] * P[j] + z[j]) * P[i] <= 0.2 * P[i] * P[j], name=f"FairnessLow[{i},{j}]")
    
                m.addConstr((C[j] * P[j] + z[j]) * P[i] - (C[i] * P[i] + z[i]) * P[j] <= 0.2 * P[i] * P[j], name=f"FairnessHigh[{j},{i}]")

# --------------------------
#  SOlve
# --------------------------

    # Solve
    m.optimize()

    # Extract weekly results
    opt_z = {i: z[i].X for i in I}
    opt_d = {i: d[i].X for i in I}
    opt_t = {(i, k): t[i, k].X for i in I for k in K}

    # Store results
    for i in I:
        coverage_start = C[i]
        coverage_end   = C[i] + opt_z[i] / P[i]

        # Compute staff sent to county i
        vacc_staff_i = sum(rV[k] * opt_t[(i, k)] for k in K)
        admin_staff_i = sum(rA[k] * opt_t[(i, k)] for k in K)

        results.append({
            "week": week,
            "county": i,
            "coverage_start": coverage_start,
            "coverage_end": coverage_end,
            "doses_sent": opt_d[i],
            "vaccinated": opt_z[i],
            "teams_1to1": opt_t[(i, "1to1")],
            "teams_3to1": opt_t[(i, "3to1")],
            "teams_7to1": opt_t[(i, "7to1")],
            "vaccinators_sent": vacc_staff_i,
            "admin_staff_sent": admin_staff_i
        })



    # Update coverage for next week (cumulative immunity)
    C = {i: C[i] + opt_z[i] / P[i] for i in I}

# ==========================================================
#                  WRITE RESULTS
# ==========================================================

with open("group22_output_20weeks.csv", "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=results[0].keys())
    writer.writeheader()
    writer.writerows(results)

print("\nSaved results to group22_output_20weeks.csv")
# Out:
# ==================== WEEK 1 ====================
#
# Starting coverage: {'Franklin': 0.0, 'Delaware': 0.0, 'Licking': 0.0, 'Fairfield': 0.0, 'Union': 0.0, 'Marion': 0.0, 'Knox': 0.0, 'Pickaway': 0.0, 'Logan': 0.0, 'Madison': 0.0, 'Crawford': 0.0, 'Morrow': 0.0, 'Hardin': 0.0, 'Fayette': 0.0, 'Wyandot': 0.0}
#
# ==================== WEEK 2 ====================
#
# Starting coverage: {'Franklin': 0.09985969211894392, 'Delaware': 0.012232839985544154, 'Licking': 0.0, 'Fairfield': 0.0, 'Union': 0.0, 'Marion': 0.0, 'Knox': 0.0, 'Pickaway': 0.0, 'Logan': 0.0, 'Madison': 0.0, 'Crawford': 0.0, 'Morrow': 0.09998051604642748, 'Hardin': 0.09999342148542859, 'Fayette': 0.09999305121256341, 'Wyandot': 0.09998130316911283}
#
# ==================== WEEK 3 ====================
#
# Starting coverage: {'Franklin': 0.18987350171753659, 'Delaware': 0.04885571888421035, 'Licking': 0.0, 'Fairfield': 0.0, 'Union': 0.0, 'Marion': 0.0, 'Knox': 0.0, 'Pickaway': 0.0, 'Logan': 0.0, 'Madison': 0.09999780369418639, 'Crawford': 0.0999855859318695, 'Morrow': 0.18996854733209007, 'Hardin': 0.1899875008223143, 'Fayette': 0.1899798485164339, 'Wyandot': 0.1899598018135926}
#
# ==================== WEEK 4 ====================
#
# Starting coverage: {'Franklin': 0.2552556471525905, 'Delaware': 0.055259995125354046, 'Licking': 0.06490064792480178, 'Fairfield': 0.09999880783490898, 'Union': 0.0999986057082305, 'Marion': 0.0999907658212263, 'Knox': 0.05525623355469239, 'Pickaway': 0.05526239582998166, 'Logan': 0.05526744059889335, 'Madison': 0.18998045287825877, 'Crawford': 0.18995339451304472, 'Morrow': 0.18996854733209007, 'Hardin': 0.1899875008223143, 'Fayette': 0.19001459245361688, 'Wyandot': 0.1899598018135926}
#
# ==================== WEEK 5 ====================
#
# Starting coverage: {'Franklin': 0.3146420821895992, 'Delaware': 0.1495591807232966, 'Licking': 0.12980129584960357, 'Fairfield': 0.18999535055614503, 'Union': 0.189986196511482, 'Marion': 0.11464232947549866, 'Knox': 0.14973061019922315, 'Pickaway': 0.11530293767495736, 'Logan': 0.11485298904198764, 'Madison': 0.18998045287825877, 'Crawford': 0.18995339451304472, 'Morrow': 0.18996854733209007, 'Hardin': 0.1899875008223143, 'Fayette': 0.19001459245361688, 'Wyandot': 0.1899598018135926}
#
# ==================== WEEK 6 ====================
#
# Starting coverage: {'Franklin': 0.37029115175591293, 'Delaware': 0.23460074128236807, 'Licking': 0.17029389176735282, 'Fairfield': 0.27099104684016645, 'Union': 0.27098060540148633, 'Marion': 0.17037059837478455, 'Knox': 0.17029507580503697, 'Pickaway': 0.1702918369316902, 'Logan': 0.17029402191602475, 'Madison': 0.27098021128461924, 'Crawford': 0.2709364339595445, 'Morrow': 0.27096612575500323, 'Hardin': 0.2709690151963686, 'Fayette': 0.2710027100271003, 'Wyandot': 0.2709638216322333}
#
# ==================== WEEK 7 ====================
#
# Starting coverage: {'Franklin': 0.4227727874965992, 'Delaware': 0.31113688510123294, 'Licking': 0.225675777996517, 'Fairfield': 0.3438919421561498, 'Union': 0.3418106272918671, 'Marion': 0.25332430435853237, 'Knox': 0.25325773712567345, 'Pickaway': 0.25325782682840503, 'Logan': 0.2532494304003472, 'Madison': 0.34387560123871647, 'Crawford': 0.3438235718060827, 'Morrow': 0.34386394633562506, 'Hardin': 0.29596737056772576, 'Fayette': 0.34389549023695365, 'Wyandot': 0.34383472001495746}
#
# ==================== WEEK 8 ====================
#
# Starting coverage: {'Franklin': 0.4804936655009979, 'Delaware': 0.38002067522251076, 'Licking': 0.29057642592131877, 'Fairfield': 0.4095027479405349, 'Union': 0.40762119881206343, 'Marion': 0.3279826397439054, 'Knox': 0.28049429896003003, 'Pickaway': 0.3185269796325493, 'Logan': 0.32791580774655527, 'Madison': 0.40947925589159034, 'Crawford': 0.40943160524672073, 'Morrow': 0.40946920143624577, 'Hardin': 0.3663574764818104, 'Fayette': 0.4094920436383851, 'Wyandot': 0.40941385435168737}
#
# ==================== WEEK 9 ====================
#
# Starting coverage: {'Franklin': 0.5324437091121969, 'Delaware': 0.4420169267878604, 'Licking': 0.35547707384612054, 'Fairfield': 0.4685506848988449, 'Union': 0.46685071318024013, 'Marion': 0.3951766806205368, 'Knox': 0.3524307730860794, 'Pickaway': 0.3866598024389459, 'Logan': 0.39511771726158185, 'Madison': 0.46851595616173597, 'Crawford': 0.4684812376879834, 'Morrow': 0.4685055807609876, 'Hardin': 0.4297085718044865, 'Fayette': 0.4685219929122368, 'Wyandot': 0.46844909787790967}
#
# ==================== WEEK 10 ====================
#
# Starting coverage: {'Franklin': 0.5791987483622759, 'Delaware': 0.4978148138809746, 'Licking': 0.4199288256227758, 'Fairfield': 0.5216914438311419, 'Union': 0.5201544875280601, 'Marion': 0.45564516129032256, 'Knox': 0.4171782984588397, 'Pickaway': 0.4479873869815631, 'Logan': 0.45559292611478786, 'Madison': 0.5216445937932398, 'Crawford': 0.521621102195743, 'Morrow': 0.5216411055751942, 'Hardin': 0.48671140056575224, 'Fayette': 0.5216454728649851, 'Wyandot': 0.5215948396746751}
#
# ==================== WEEK 11 ====================
#
# Starting coverage: {'Franklin': 0.6212785786066977, 'Delaware': 0.5480320718085777, 'Licking': 0.4779337797055674, 'Fairfield': 0.5695211072829367, 'Union': 0.5681320673164066, 'Marion': 0.5100806451612903, 'Knox': 0.4754573361734118, 'Pickaway': 0.5031854306766627, 'Logan': 0.5100141043723554, 'Madison': 0.5694801344139158, 'Crawford': 0.5694517849421035, 'Morrow': 0.5694602944860412, 'Hardin': 0.5380238142227485, 'Fayette': 0.5694531304287402, 'Wyandot': 0.5694119846685987}
#
# ==================== WEEK 12 ====================
#
# Starting coverage: {'Franklin': 0.6591506470161902, 'Delaware': 0.5932276039434206, 'Licking': 0.5301355341864162, 'Fairfield': 0.612564227894279, 'Union': 0.611313283417688, 'Marion': 0.5590679635557744, 'Knox': 0.5279100363362986, 'Pickaway': 0.5528652788056243, 'Logan': 0.5590105240316805, 'Madison': 0.612527728360897, 'Crawford': 0.6125018017585163, 'Morrow': 0.6124919976619256, 'Hardin': 0.5842049865140451, 'Fayette': 0.6125008685984297, 'Wyandot': 0.6124614377862952}
#
# ==================== WEEK 13 ====================
#
# Starting coverage: {'Franklin': 0.6932352136653829, 'Delaware': 0.63390148172428, 'Licking': 0.5771181948966456, 'Fairfield': 0.6513036325270325, 'Union': 0.6501721950335327, 'Marion': 0.603161167200197, 'Knox': 0.5751159002631249, 'Pickaway': 0.5975739245149457, 'Logan': 0.6031029619181946, 'Madison': 0.6512705629131801, 'Crawford': 0.6512516215826647, 'Morrow': 0.6512372310518553, 'Hardin': 0.6257811986053549, 'Fayette': 0.6512403585574318, 'Wyandot': 0.6512106197999439}
#
# ==================== WEEK 14 ====================
#
# Starting coverage: {'Franklin': 0.7239112499198187, 'Delaware': 0.6705075514989537, 'Licking': 0.6194063754069811, 'Fairfield': 0.6861685006139652, 'Union': 0.6851549755301795, 'Marion': 0.6428373553311992, 'Knox': 0.6175917804786367, 'Pickaway': 0.6378100968499629, 'Logan': 0.6427904958229358, 'Madison': 0.6861259361753531, 'Crawford': 0.6861096430115793, 'Morrow': 0.6861135079466698, 'Hardin': 0.6631800539438194, 'Fayette': 0.6860885275519423, 'Wyandot': 0.6860802094045059}
#
# ==================== WEEK 15 ====================
#
# Starting coverage: {'Franklin': 0.7515201249278368, 'Delaware': 0.7034534345242598, 'Licking': 0.6574651970275502, 'Fairfield': 0.7175462858096591, 'Union': 0.7166380836853921, 'Marion': 0.67854284658951, 'Knox': 0.6558232051121413, 'Pickaway': 0.6740242607548504, 'Logan': 0.6785071064337636, 'Madison': 0.7175111462520042, 'Crawford': 0.7174842646422909, 'Morrow': 0.7174826731984303, 'Hardin': 0.6968620485494375, 'Fayette': 0.7174623028281566, 'Wyandot': 0.7174441432177245}
#
# ==================== WEEK 16 ====================
#
# Starting coverage: {'Franklin': 0.7763678175157025, 'Delaware': 0.7331047292470353, 'Licking': 0.6917165139698643, 'Fairfield': 0.7457886768159656, 'Union': 0.7449700924415443, 'Marion': 0.7106777887219897, 'Knox': 0.6902330535020674, 'Pickaway': 0.7066186170726213, 'Logan': 0.7106433763697514, 'Madison': 0.7457556390151765, 'Crawford': 0.7457358381780618, 'Morrow': 0.7457344058785873, 'Hardin': 0.7271561081507795, 'Fayette': 0.7457091237579043, 'Wyandot': 0.7456763578573431}
#
# ==================== WEEK 17 ====================
#
# Starting coverage: {'Franklin': 0.7987308145746193, 'Delaware': 0.7597934158661321, 'Licking': 0.7225443217341452, 'Fairfield': 0.7712056365565505, 'Union': 0.7704716889056205, 'Marion': 0.7395961585816302, 'Knox': 0.721197218393685, 'Pickaway': 0.7359471025451269, 'Logan': 0.7395681892155798, 'Madison': 0.7711668972787771, 'Crawford': 0.7711526449815019, 'Morrow': 0.771147048181034, 'Hardin': 0.754424051049273, 'Fayette': 0.7711069418386493, 'Wyandot': 0.771104047863887}
#
# ==================== WEEK 18 ====================
#
# Starting coverage: {'Franklin': 0.7999997050806492, 'Delaware': 0.7838136540514191, 'Licking': 0.7502893487219979, 'Fairfield': 0.794083284653259, 'Union': 0.7934217314315194, 'Marion': 0.7656365427234672, 'Knox': 0.7490759303345446, 'Pickaway': 0.762347565880498, 'Logan': 0.7656070304871432, 'Madison': 0.7940304407985768, 'Crawford': 0.7940229664152212, 'Morrow': 0.7940267765190527, 'Hardin': 0.7789619104006315, 'Fayette': 0.793968452505038, 'Wyandot': 0.7939609236234457}
#
# ==================== WEEK 19 ====================
#
# Starting coverage: {'Franklin': 0.7999997050806492, 'Delaware': 0.7999966381752015, 'Licking': 0.7752598730110654, 'Fairfield': 0.7999964235047271, 'Union': 0.799988845665844, 'Marion': 0.7890605762127555, 'Knox': 0.7741667710813182, 'Pickaway': 0.7861095916857042, 'Logan': 0.7890419876315502, 'Madison': 0.799982429553491, 'Crawford': 0.7999807812424926, 'Morrow': 0.7999832994683667, 'Hardin': 0.7999802644562857, 'Fayette': 0.7999791536376903, 'Wyandot': 0.7999906515845563}
#
# ==================== WEEK 20 ====================
#
# Starting coverage: {'Franklin': 0.7999997050806492, 'Delaware': 0.7999966381752015, 'Licking': 0.797731722355028, 'Fairfield': 0.7999964235047271, 'Union': 0.799988845665844, 'Marion': 0.7999876877616351, 'Knox': 0.7967359979952388, 'Pickaway': 0.7999935647865117, 'Logan': 0.7999999999999998, 'Madison': 0.799982429553491, 'Crawford': 0.7999807812424926, 'Morrow': 0.7999832994683667, 'Hardin': 0.7999802644562857, 'Fayette': 0.7999791536376903, 'Wyandot': 0.7999906515845563}
#
# Saved results to vaccine_results_20_weeks.csv
